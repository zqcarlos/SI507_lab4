# %%
import pandas as pd
import itertools
data_3 = pd.read_csv('/Users/zhouqi/Desktop/winter19/SI507/lab/lab4/movies_clean.csv',keep_default_na=False)
data_3_rate_first = data_3['MPAA Rating']
data_3_rate_first.replace('NA','Not Rated',inplace=True)

data_3_rate_list = data_3_rate_first.sample(15)
iter = itertools.cycle(data_3_rate_list)
a = 0
fake_rate = []
for b in iter:
    fake_rate.append(b)
    a = a +1
    if a == 15:
        break
        
# print(fake_rate)
# print(data_3_rate_first)
# for i in data_3_rate_first:
#     if i  = 'NA':
#         i = 'Not Rated'
#     else:
#         i = 'R'

#data_3_rate_first.replace('NA','Not Rated')
print(data_3_rate)
# Out:
# 0               R
# 1               R
# 2              NA
# 3              NA
# 4               R
# 5              NA
# 6               R
# 7               R
# 8               R
# 9              NA
# 10             NA
# 11             NA
# 12             NA
# 13             NA
# 14             NA
# 15             NA
# 16             NA
# 17             NA
# 18             NA
# 19             NA
# 20              R
# 21             PG
# 22             NA
# 23      Not Rated
# 24             NA
# 25             NA
# 26             NA
# 27              R
# 28              R
# 29              R
#           ...
# 3115           PG
# 3116        PG-13
# 3117        PG-13
# 3118        PG-13
# 3119           NA
# 3120           NA
# 3121        PG-13
# 3122            R
# 3123        PG-13
# 3124            R
# 3125        PG-13
# 3126            R
# 3127        PG-13
# 3128            R
# 3129           PG
# 3130           PG
# 3131            R
# 3132            R
# 3133           PG
# 3134            R
# 3135           PG
# 3136           PG
# 3137            R
# 3138        PG-13
# 3139            R
# 3140            R
# 3141            R
# 3142           PG
# 3143           PG
# 3144        PG-13
# Name: MPAA Rating, Length: 3145, dtype: object

# %%
import pandas as pd
import itertools
data_3 = pd.read_csv('/Users/zhouqi/Desktop/winter19/SI507/lab/lab4/movies_clean.csv',keep_default_na=False)
data_3_rate_first = data_3['MPAA Rating']
data_3_rate_first.replace('NA','Not Rated',inplace=True)
print(data_3_rate_first)
# Out:
# 0               R
# 1               R
# 2       Not Rated
# 3       Not Rated
# 4               R
# 5       Not Rated
# 6               R
# 7               R
# 8               R
# 9       Not Rated
# 10      Not Rated
# 11      Not Rated
# 12      Not Rated
# 13      Not Rated
# 14      Not Rated
# 15      Not Rated
# 16      Not Rated
# 17      Not Rated
# 18      Not Rated
# 19      Not Rated
# 20              R
# 21             PG
# 22      Not Rated
# 23      Not Rated
# 24      Not Rated
# 25      Not Rated
# 26      Not Rated
# 27              R
# 28              R
# 29              R
#           ...
# 3115           PG
# 3116        PG-13
# 3117        PG-13
# 3118        PG-13
# 3119    Not Rated
# 3120    Not Rated
# 3121        PG-13
# 3122            R
# 3123        PG-13
# 3124            R
# 3125        PG-13
# 3126            R
# 3127        PG-13
# 3128            R
# 3129           PG
# 3130           PG
# 3131            R
# 3132            R
# 3133           PG
# 3134            R
# 3135           PG
# 3136           PG
# 3137            R
# 3138        PG-13
# 3139            R
# 3140            R
# 3141            R
# 3142           PG
# 3143           PG
# 3144        PG-13
# Name: MPAA Rating, Length: 3145, dtype: object

# %%
import pandas as pd
import itertools
data_3 = pd.read_csv('/Users/zhouqi/Desktop/winter19/SI507/lab/lab4/movies_clean.csv',keep_default_na=False)
data_3_rate_first = data_3['MPAA Rating']
data_3_rate_first.replace('NA','Not Rated',inplace=True)

data_3_rate_list = data_3_rate_first.sample(15)
iter = itertools.cycle(data_3_rate_list)
a = 0
fake_rate = []
for b in iter:
    fake_rate.append(b)
    a = a +1
    if a == 15:
        break
        
print(fake_rate)
# Out:
# ['Not Rated', 'R', 'Not Rated', 'PG', 'R', 'R', 'PG-13', 'R', 'R', 'PG', 'PG-13', 'PG-13', 'R', 'PG-13', 'PG-13']

# %%
import pandas as pd
import random
import itertools
import numpy as np
data_3 = pd.read_csv('/Users/zhouqi/Desktop/winter19/SI507/lab/lab4/movies_clean.csv',keep_default_na=False)
data_3_fake_name = data_3['Title']
data_3_fake_name_list = data_3_fake_name.sample(15)
iter = itertools.cycle(data_3_fake_name_list)
j=0
fake_name = []
for i in iter:
    if len(data_3_fake_name_list)<45:
        fake_name_split = str(data_3_fake_name_list).split(' ')
        i = fake_name_split.reverse()
        fake_name.append(i)
        j = j + 1
        if j == 15:
            break
            
print(fake_name)
print(type(data_3_fake_name_list))
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# <class 'pandas.core.series.Series'>

# %%
a = str(data_3_fake_name_list)
b = a.split()
print(b)
b.sort(reverse=True)
print(b)
# Out:
# ['49', 'The', 'Princess', 'and', 'the', 'Cobbler', '2065', 'Kicking', 'and', 'Screaming', '1484', 'City', 'by', 'the', 'Sea', '1267', 'Big', 'Trouble', '2242', 'Mercury', 'Rising', '1161', 'Armageddon', '1382', 'Collateral', 'Damage', '77', 'Back', 'to', 'the', 'Future', 'Part', 'II', '2822', 'Step', 'Up', '2697', 'The', 'Siege', '1174', 'Assault', 'On', 'Precinct', '13', '2141', 'Loser', '2609', 'Road', 'Trip', '1979', 'Indiana', 'Jones', 'and', 'the', 'Kingdom', 'of', 'the', 'Crystal', 'S...', '3099', 'Winter', 'Passing', 'Name:', 'Title,', 'dtype:', 'object']
# ['to', 'the', 'the', 'the', 'the', 'the', 'of', 'object', 'dtype:', 'by', 'and', 'and', 'and', 'Winter', 'Up', 'Trouble', 'Trip', 'Title,', 'The', 'The', 'Step', 'Siege', 'Sea', 'Screaming', 'S...', 'Road', 'Rising', 'Princess', 'Precinct', 'Passing', 'Part', 'On', 'Name:', 'Mercury', 'Loser', 'Kingdom', 'Kicking', 'Jones', 'Indiana', 'II', 'Future', 'Damage', 'Crystal', 'Collateral', 'Cobbler', 'City', 'Big', 'Back', 'Assault', 'Armageddon', '77', '49', '3099', '2822', '2697', '2609', '2242', '2141', '2065', '1979', '1484', '1382', '13', '1267', '1174', '1161']

# %%
print(b.reverse())
# Out:
# None

# %%
print (' '.join(b))
# Out:
# to the the the the the of object dtype: by and and and Winter Up Trouble Trip Title, The The Step Siege Sea Screaming S... Road Rising Princess Precinct Passing Part On Name: Mercury Loser Kingdom Kicking Jones Indiana II Future Damage Crystal Collateral Cobbler City Big Back Assault Armageddon 77 49 3099 2822 2697 2609 2242 2141 2065 1979 1484 1382 13 1267 1174 1161

# %%
import pandas as pd
import random
import itertools
import numpy as np
data_3 = pd.read_csv('/Users/zhouqi/Desktop/winter19/SI507/lab/lab4/movies_clean.csv',keep_default_na=False)
data_3_fake_name_first = data_3['Title']
data_3_fake_name_second = []
for i in data_3_fake_name_first:
    if len(data_3_fake_name_first) < 45:
        data_3_fake_name_second.append(i)
# data_3_fake_name_list = random.sample(data_3_fake_name_second,15)
# a = str(data_3_fake_name_list)
# iter = itertools.cycle(data_3_fake_name_list)
# j=0
# fake_name = []
# for i in iter:
#     if len(data_3_fake_name_list)<45:
#         fake_name_split = str(data_3_fake_name_list).split(' ')
#         i = fake_name_split.reverse()
#         fake_name.append(i)
#         j = j + 1
#         if j == 15:
#             break
            
# a = str(data_3_fake_name_list)
# b = a.split()
# print(b)
# b.sort(reverse=True)
# print(b)
print(data_3_fake_name_second)
# Out:
# []

# %%
import pandas as pd
import random
import itertools
import numpy as np
data_3 = pd.read_csv('/Users/zhouqi/Desktop/winter19/SI507/lab/lab4/movies_clean.csv',keep_default_na=False)
data_3_fake_name_first = data_3['Title']
data_3_fake_name_second = []
for i in data_3_fake_name_first:
    a = list(data_3_fake_name_first[i])
    if len(a) < 45:
        data_3_fake_name_second.append(i)
print(data_3_fake_name_second)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-adc8c4075341> in <module>
#       6 data_3_fake_name_first = data_3['Title']
#       7 data_3_fake_name_second = []
# ----> 8 a = list(data_3_fake_name_first[i])
#       9 for i in data_3_fake_name_first:
#      10     a = list(data_3_fake_name_first[i])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#     769             if not is_scalar(result):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    3116         try:
#    3117             return self._engine.get_value(s, k,
# -> 3118                                           tz=getattr(series.dtype, 'tz', None))
#    3119         except KeyError as e1:
#    3120             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: 'The Land Girls'

# %%
data_3 = pd.read_csv('/Users/zhouqi/Desktop/winter19/SI507/lab/lab4/movies_clean.csv',keep_default_na=False)
data_3_fake_name = data_3['Title']
iter_1 = list(itertools.cycle(data_3_fake_name))
# for i in iter_1:
#     if len(iter_1[i]) < 45:
#         iter_1[i] = iter_1[i]
#     else:
#         iter_1[i] = 'Sorryfortoolong'
print(iter_1)
# data_3_fake_name_list = data_3_fake_name.sample(15)
# iter = itertools.cycle(data_3_fake_name_list)
# j=0
# fake_name = []
# for i in iter:
#     if len(data_3_fake_name_list)<22:
#         fake_name.append(i+' '+i)
#         j = j + 1
#         if j == 15:
#             break

# %%
import pandas as pd
import random
import itertools
import numpy as np

data_3 = pd.read_csv('/Users/zhouqi/Desktop/winter19/SI507/lab/lab4/movies_clean.csv',keep_default_na=False)
data_3_fake_name = data_3['Title']
data_3_fake_name_list = data_3_fake_name.sample(15)
iter = itertools.cycle(data_3_fake_name_list)
j=0
fake_name = []
for i in iter:
    if len(i)<23:
        fake_name.append(i + '$' + i[::-1])
        j = j + 1
    elif len(i)<45:
        fake_name.append(i[::-1]+'$')
        j = j + 1
    else:
        fake_name.append(i[1:46])
        j = j + 1
    if j == 15:
        break
print(fake_name)
# Out:
# ['Slumdog Millionaire$erianoilliM godmulS', 'Ben-Hur$ruH-neB', 'The Little Vampire$eripmaV elttiL ehT', 'Wing Commander$rednammoC gniW', 'Company Man$naM ynapmoC', 'Time Changer$regnahC emiT', 'Money Train$niarT yenoM', 'The Cooler$relooC ehT', 'emodrednuhT dnoyeB xaM daM$', 'Casino$onisaC', 'Kill Bill: Volume 2$2 emuloV :lliB lliK', 'The Black Hole$eloH kcalB ehT', 'Nixon$noxiN', '0003 raeY eht fo agaS A :htraE dleifelttaB$', 'Beverly Hills Cop III$III poC slliH ylreveB']

# %%
import pandas as pd
import numpy as np
data_2 = pd.read_csv('/Users/zhouqi/Desktop/winter19/SI507/lab/lab4/movies_clean.csv',keep_default_na=False)
data_2_test = data_2['MPAA Rating']
x = np.zeros(len(data_2_test))
median_rating_str = ' '
median_rating_1 = 0
for i in range(len(data_2_test)):
    if data_2_test[i] == 'G':
        x[i]=1
    elif data_2_test[i] == 'PG':
        x[i] = 2
    elif data_2_test[i] == 'PG-13':
        x[i] = 3
    elif data_2_test[i] == 'R':
        x[i] = 4
    elif data_2_test[i] == 'NC-17':
        x[i] = 5
median_rating_1 = np.median(x)
if median_rating_1 == 1.0:
    median_rating_str = 'G'
elif median_rating_1 == 2.0:
    median_rating_str = 'PG'
elif median_rating_1 == 3.0:
    median_rating_str = 'PG-13'
elif median_rating_1 == 4.0:
    median_rating_str = 'R'
elif median_rating_1 == 5.0:
    median_rating_str = 'NC-17'
print(median_rating_str)
# Out:
# PG-13

# %%
data = pd.read_csv("movies_dataset_group.csv")

# %%
data
# Out:
#                                            Title   US Gross  Worldwide Gross  \
# 0                                 The Land Girls     146083           146083
# 1                         First Love, Last Rites      10876            10876
# 2                     I Married a Strange Person     203134           203134
# 3                           Let's Talk About Sex     373615           373615
# 4                                           Slam    1009819          1087521
# 5                            Mississippi Mermaid      24551          2624551
# 6                                      Following      44705            44705
# 7                                        Foolish    6026908          6026908
# 8                                        Pirates    1641825          6341825
# 9                                Duel in the Sun   20400000         20400000
# 10                                     Tom Jones   37600000         37600000
# 11                                       Oliver!   37402877         37402877
# 12                         To Kill A Mockingbird   13129846         13129846
# 13                              Tora, Tora, Tora   29548291         29548291
# 14                             Hollywood Shuffle    5228617          5228617
# 15                Over the Hill to the Poorhouse    3000000          3000000
# 16                                        Wilson    2000000          2000000
# 17                                  Darling Lili    5000000          5000000
# 18                          The Ten Commandments   80000000         80000000
# 19                                  12 Angry Men          0                0
# 20                                Twelve Monkeys   57141459        168841459
# 21                                          1776          0                0
# 22                                          1941   34175000         94875000
# 23                                Chacun sa nuit      18435            18435
# 24                         2001: A Space Odyssey   56700000         68700000
# 25                  20,000 Leagues Under the Sea   28200000         28200000
# 26                  20,000 Leagues Under the Sea    8000000          8000000
# 27                       24 7: Twenty Four Seven      72544            72544
# 28                              Twin Falls Idaho     985341          1027228
# 29    Three Kingdoms: Resurrection of the Dragon          0         22139590
# ...                                          ...        ...              ...
# 3115                      Extraordinary Measures   12482741         12697741
# 3116                                       X-Men  157299717        334627820
# 3117                                          X2  214949694        407711549
# 3118                       X-Men: The Last Stand  234362462        459359555
# 3119                          The Exploding Girl      25572            25572
# 3120                             The Expendables  101384023        240484023
# 3121                     XXX: State of the Union   26873932         71073932
# 3122                                   The Yards     882710          2282710
# 3123  The Divine Secrets of the Ya-Ya Sisterhood   69586544         73826768
# 3124                         You Can Count on Me    9180275         11005992
# 3125                                    Year One   43337279         57604723
# 3126                                         Yes     396035           661221
# 3127                                     Yes Man   97690976        225990976
# 3128                                 You Kill Me    2426851          2426851
# 3129                        Yours, Mine and Ours   53359917         72359917
# 3130                             You've Got Mail  115821495        250800000
# 3131                             Youth in Revolt   15285588         17585588
# 3132     Y Tu Mama Tambien (And Your Mother Too)   13649881         33649881
# 3133                                    Yu-Gi-Oh   19762690         28762690
# 3134                          The Young Unknowns      58163            58163
# 3135                          The Young Victoria   11001272         11001272
# 3136                                     Zathura   28045540         58545540
# 3137                                 Zero Effect    2080693          2080693
# 3138                                   Zoolander   45172250         60780981
# 3139                                  Zombieland   75590286         98690286
# 3140                  Zack and Miri Make a Porno   31452765         36851125
# 3141                                      Zodiac   33080084         83080084
# 3142                                        Zoom   11989328         12506188
# 3143                         The Legend of Zorro   45575336        141475336
# 3144                           The Mask of Zorro   93828745        233700000
#
#       US DVD Sales  Production Budget Release Date MPAA Rating  \
# 0              NaN          8000000.0    12-Jun-98           R
# 1              NaN           300000.0     7-Aug-98           R
# 2              NaN           250000.0    28-Aug-98         NaN
# 3              NaN           300000.0    11-Sep-98         NaN
# 4              NaN          1000000.0     9-Oct-98           R
# 5              NaN          1600000.0    15-Jan-99         NaN
# 6              NaN             6000.0     4-Apr-99           R
# 7              NaN          1600000.0     9-Apr-99           R
# 8              NaN         40000000.0     1-Jul-86           R
# 9              NaN          6000000.0    31-Dec-46         NaN
# 10             NaN          1000000.0     7-Oct-63         NaN
# 11             NaN         10000000.0    11-Dec-68         NaN
# 12             NaN          2000000.0    25-Dec-62         NaN
# 13             NaN         25000000.0    23-Sep-70         NaN
# 14             NaN           100000.0     1-Mar-87         NaN
# 15             NaN           100000.0    17-Sep-20         NaN
# 16             NaN          5200000.0     1-Aug-44         NaN
# 17             NaN         22000000.0     1-Jan-70         NaN
# 18             NaN         13500000.0     5-Oct-56         NaN
# 19             NaN           340000.0    13-Apr-57         NaN
# 20             NaN         29000000.0    27-Dec-95           R
# 21             NaN          4000000.0     9-Nov-72          PG
# 22             NaN         32000000.0    14-Dec-79         NaN
# 23             NaN          1900000.0    29-Jun-07   Not Rated
# 24             NaN         10500000.0     2-Apr-68         NaN
# 25             NaN          5000000.0    23-Dec-54         NaN
# 26             NaN           200000.0    24-Dec-16         NaN
# 27             NaN          2000000.0    15-Apr-98           R
# 28             NaN           500000.0    30-Jul-99           R
# 29             NaN         20000000.0     3-Apr-08           R
# ...            ...                ...          ...         ...
# 3115     5267433.0         31000000.0    22-Jan-10          PG
# 3116           NaN         75000000.0    14-Jul-00       PG-13
# 3117           NaN        125000000.0     2-May-03       PG-13
# 3118   103555667.0        150000000.0    26-May-06       PG-13
# 3119           NaN            40000.0    12-Mar-10         NaN
# 3120           NaN         82000000.0    13-Aug-10         NaN
# 3121           NaN         60000000.0    29-Apr-05       PG-13
# 3122           NaN         20000000.0    20-Oct-00           R
# 3123           NaN         27000000.0     7-Jun-02       PG-13
# 3124           NaN          1200000.0    10-Nov-00           R
# 3125    14813995.0         60000000.0    19-Jun-09       PG-13
# 3126           NaN          1700000.0    24-Jun-05           R
# 3127    26601131.0         50000000.0    19-Dec-08       PG-13
# 3128           NaN          4000000.0    22-Jun-07           R
# 3129    26979166.0         45000000.0    23-Nov-05          PG
# 3130           NaN         65000000.0    18-Dec-98          PG
# 3131     3654607.0         18000000.0     8-Jan-10           R
# 3132           NaN          5000000.0    15-Mar-02           R
# 3133           NaN         20000000.0    13-Aug-04          PG
# 3134           NaN           800000.0    11-Apr-03           R
# 3135     3273039.0         35000000.0    18-Dec-09          PG
# 3136    22025352.0         65000000.0    11-Nov-05          PG
# 3137           NaN          5000000.0    30-Jan-98           R
# 3138           NaN         28000000.0    28-Sep-01       PG-13
# 3139    28281155.0         23600000.0     2-Oct-09           R
# 3140    21240321.0         24000000.0    31-Oct-08           R
# 3141    20983030.0         85000000.0     2-Mar-07           R
# 3142     6679409.0         35000000.0    11-Aug-06          PG
# 3143           NaN         80000000.0    28-Oct-05          PG
# 3144           NaN         65000000.0    17-Jul-98       PG-13
#
#       Running Time (min)             Distributor  \
# 0                    NaN                Gramercy
# 1                    NaN                  Strand
# 2                    NaN               Lionsgate
# 3                    NaN               Fine Line
# 4                    NaN                 Trimark
# 5                    NaN                     MGM
# 6                    NaN               Zeitgeist
# 7                    NaN                 Artisan
# 8                    NaN                     NaN
# 9                    NaN                     NaN
# 10                   NaN                     NaN
# 11                   NaN           Sony Pictures
# 12                   NaN               Universal
# 13                   NaN                     NaN
# 14                   NaN                     NaN
# 15                   NaN                     NaN
# 16                   NaN                     NaN
# 17                   NaN                     NaN
# 18                   NaN                     NaN
# 19                   NaN          United Artists
# 20                   NaN               Universal
# 21                   NaN           Sony/Columbia
# 22                   NaN               Universal
# 23                   NaN                  Strand
# 24                   NaN                     NaN
# 25                   NaN    Walt Disney Pictures
# 26                   NaN                     NaN
# 27                   NaN           October Films
# 28                   NaN  Sony Pictures Classics
# 29                   NaN                     NaN
# ...                  ...                     ...
# 3115                 NaN               CBS Films
# 3116               104.0        20th Century Fox
# 3117               133.0        20th Century Fox
# 3118                 NaN        20th Century Fox
# 3119                79.0   Oscilloscope Pictures
# 3120               103.0               Lionsgate
# 3121                 NaN           Sony Pictures
# 3122                 NaN                 Miramax
# 3123               116.0            Warner Bros.
# 3124                 NaN       Paramount Vantage
# 3125                97.0           Sony Pictures
# 3126                 NaN  Sony Pictures Classics
# 3127               104.0            Warner Bros.
# 3128                92.0               IFC Films
# 3129                90.0      Paramount Pictures
# 3130               119.0            Warner Bros.
# 3131                 NaN     Weinstein/Dimension
# 3132                 NaN               IFC Films
# 3133                 NaN            Warner Bros.
# 3134                 NaN        Indican Pictures
# 3135                 NaN              Apparition
# 3136               113.0           Sony Pictures
# 3137                 NaN           Sony Pictures
# 3138                89.0      Paramount Pictures
# 3139                87.0           Sony Pictures
# 3140               101.0           Weinstein Co.
# 3141               157.0      Paramount Pictures
# 3142                 NaN           Sony Pictures
# 3143               129.0           Sony Pictures
# 3144               136.0           Sony Pictures
#
#                             Source        Major Genre         Creative Type  \
# 0                              NaN                NaN                   NaN
# 1                              NaN              Drama                   NaN
# 2                              NaN             Comedy                   NaN
# 3                              NaN             Comedy                   NaN
# 4              Original Screenplay              Drama  Contemporary Fiction
# 5                              NaN                NaN                   NaN
# 6                              NaN                NaN                   NaN
# 7              Original Screenplay             Comedy  Contemporary Fiction
# 8                              NaN                NaN                   NaN
# 9                              NaN                NaN                   NaN
# 10                             NaN                NaN                   NaN
# 11                             NaN            Musical                   NaN
# 12                             NaN                NaN                   NaN
# 13                             NaN                NaN                   NaN
# 14                             NaN                NaN                   NaN
# 15                             NaN                NaN                   NaN
# 16                             NaN                NaN                   NaN
# 17                             NaN                NaN                   NaN
# 18                             NaN                NaN                   NaN
# 19             Original Screenplay              Drama                   NaN
# 20             Based on Short Film              Drama       Science Fiction
# 21                   Based on Play              Drama    Historical Fiction
# 22             Original Screenplay             Comedy    Historical Fiction
# 23             Original Screenplay  Thriller/Suspense                   NaN
# 24             Original Screenplay                NaN       Science Fiction
# 25       Based on Book/Short Story          Adventure                   NaN
# 26       Based on Book/Short Story          Adventure                   NaN
# 27             Original Screenplay             Comedy                   NaN
# 28             Original Screenplay              Drama  Contemporary Fiction
# 29       Based on Book/Short Story             Action    Historical Fiction
# ...                            ...                ...                   ...
# 3115     Based on Real Life Events              Drama         Dramatization
# 3116  Based on Comic/Graphic Novel             Action            Super Hero
# 3117  Based on Comic/Graphic Novel             Action            Super Hero
# 3118  Based on Comic/Graphic Novel             Action            Super Hero
# 3119                           NaN                NaN                   NaN
# 3120           Original Screenplay             Action  Contemporary Fiction
# 3121           Original Screenplay             Action  Contemporary Fiction
# 3122                           NaN              Drama                   NaN
# 3123     Based on Book/Short Story             Comedy  Contemporary Fiction
# 3124           Original Screenplay              Drama  Contemporary Fiction
# 3125           Original Screenplay             Comedy    Historical Fiction
# 3126           Original Screenplay              Drama                   NaN
# 3127     Based on Book/Short Story             Comedy  Contemporary Fiction
# 3128           Original Screenplay       Black Comedy  Contemporary Fiction
# 3129                        Remake             Comedy  Contemporary Fiction
# 3130                 Based on Play              Drama  Contemporary Fiction
# 3131     Based on Book/Short Story             Comedy  Contemporary Fiction
# 3132           Original Screenplay              Drama  Contemporary Fiction
# 3133                   Based on TV          Adventure          Kids Fiction
# 3134                           NaN                NaN                   NaN
# 3135     Based on Real Life Events              Drama         Dramatization
# 3136     Based on Book/Short Story          Adventure               Fantasy
# 3135                 NaN                    76.0          7.2      8408.0
# 3136         Jon Favreau                    75.0          NaN         NaN
# 3137                 NaN                    66.0          6.8      8489.0
# 3138         Ben Stiller                    62.0          6.4     69296.0
# 3139     Ruben Fleischer                    89.0          7.8     81629.0
# 3140         Kevin Smith                    65.0          7.0     55687.0
# 3141       David Fincher                    89.0          NaN         NaN
# 3142        Peter Hewitt                     3.0          3.4      7424.0
# 3143     Martin Campbell                    26.0          5.7     21161.0
# 3144     Martin Campbell                    82.0          6.7      4789.0
#
# [3145 rows x 16 columns]

# %%
import pandas as pd
import numpy as np
import itertools
import random

def SI507_HW4():
    test()

def part_1():
    data=pd.read_csv('movies_dataset_group.csv')
    date = data['Release Date']
    for i in range(len(date)):
        if len(date[i]) < 9:
            date[i] = '0' + date[i]
    date_nonan = data.fillna('NA')
    date_nonan.to_csv('movies_clean.csv')
    return

def median_rating():
    data_2 = pd.read_csv('movies_clean.csv',keep_default_na=False)
    data_2_test = data_2['MPAA Rating']
    x = np.zeros(len(data_2_test))
    median_rating_str = ' '
    median_rating_1 = 0
    for i in range(len(data_2_test)):
        if data_2_test[i] == 'G':
            x[i]=1
        elif data_2_test[i] == 'PG':
            x[i] = 2
        elif data_2_test[i] == 'PG-13':
            x[i] = 3
        elif data_2_test[i] == 'R':
            x[i] = 4
        elif data_2_test[i] == 'NC-17':
            x[i] = 5
    median_rating_1 = np.median(x)
    if median_rating_1 == 1.0:
        median_rating_str = 'G'
    elif median_rating_1 == 2.0:
        median_rating_str = 'PG'
    elif median_rating_1 == 3.0:
        median_rating_str = 'PG-13'
    elif median_rating_1 == 4.0:
        median_rating_str = 'R'
    elif median_rating_1 == 5.0:
        median_rating_str = 'NC-17'
    print(median_rating_str)
    return(median_rating_str)



def part_3_1():
    data_3 = pd.read_csv('movies_clean.csv',keep_default_na=False)
    data_3_fake_name = data_3['Title']
    data_3_fake_name_list = data_3_fake_name.sample(15)
    iter = itertools.cycle(data_3_fake_name_list)
    j=0
    fake_name = []
#    for i in iter:
#        if len(data_3_fake_name_list)<22:
#            fake_name.append(i+' '+i)
#            j = j + 1
#            if j == 15:
#                break
    for i in iter:
        if len(i)<23:
            fake_name.append(i + '$' + i[::-1])
            j = j + 1
            print(len(i))
        elif len(i)<45:
            fake_name.append(i[::-1]+'$')
            j = j + 1
            print(len(i))
        else:
            fake_name.append(i[1:46])
            j = j + 1
            print(len(i))
        if j == 15:
            break
    print(len(fake_name))
    return(fake_name)

def part_3_2():
    data_3 = pd.read_csv('movies_clean.csv',keep_default_na=False)
    data_3_rate = data_3['MPAA Rating']
    data_3_rate.replace('NA','Not Rated',inplace=True)
    data_3_rate_list = data_3_rate.sample(15)
    iter = itertools.cycle(data_3_rate_list)
    a = 0
    fake_rate = []
    for b in iter:
        fake_rate.append(b)
        a = a +1
        if a == 15:
            break
    return(fake_rate)

def sample_fake_movies():
    a = part_3_1()
    b = part_3_2()
    sample_fake_movie = []
    for i in range(len(a)):
        sample_fake_movie.append(a[i] + ' - ' + b[i])
        print(sample_fake_movie[i])

def test():
    part_1()
    median_rating()
    sample_fake_movies()

# %%
SI507_HW4()
# Out:
# /Users/zhouqi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# PG-13
# 13
# 19
# 15
# 25
# 11
# 13
# 19
# 7
# 9
# 35
# 6
# 14
# 14
# 36
# 13
# 15
# First Morning$gninroM tsriF - R
# L'auberge espagnole$elongapse egrebua'L - PG-13
# The Illusionist$tsinoisullI ehT - PG-13
# eripmE tsoL ehT :sitnaltA$ - PG-13
# Fool's Gold$dloG s'looF - PG-13
# The New World$dlroW weN ehT - PG
# My Fellow Americans$snaciremA wolleF yM - R
# Slither$rehtilS - PG
# Boomerang$gnaremooB - R
# yrraL dna kcuhC uoY ecnuonorP woN I$ - PG
# Cavite$etivaC - Not Rated
# The Dark Hours$sruoH kraD ehT - R
# At First Sight$thgiS tsriF tA - PG-13
# mooD fo elpmeT eht dna senoJ anaidnI$ - PG
# Mononoke-hime$emih-ekononoM - R

# %%
date_nonan
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-4ac57c3a107c> in <module>
# ----> 1 date_nonan
#
# NameError: name 'date_nonan' is not defined

# %%
data_2
# Out:
#       Unnamed: 0                                       Title   US Gross  \
# 0              0                              The Land Girls     146083
# 1              1                      First Love, Last Rites      10876
# 2              2                  I Married a Strange Person     203134
# 3              3                        Let's Talk About Sex     373615
# 4              4                                        Slam    1009819
# 5              5                         Mississippi Mermaid      24551
# 6              6                                   Following      44705
# 7              7                                     Foolish    6026908
# 8              8                                     Pirates    1641825
# 9              9                             Duel in the Sun   20400000
# 10            10                                   Tom Jones   37600000
# 11            11                                     Oliver!   37402877
# 12            12                       To Kill A Mockingbird   13129846
# 13            13                            Tora, Tora, Tora   29548291
# 14            14                           Hollywood Shuffle    5228617
# 15            15              Over the Hill to the Poorhouse    3000000
# 16            16                                      Wilson    2000000
# 17            17                                Darling Lili    5000000
# 18            18                        The Ten Commandments   80000000
# 19            19                                12 Angry Men          0
# 20            20                              Twelve Monkeys   57141459
# 21            21                                        1776          0
# 22            22                                        1941   34175000
# 23            23                              Chacun sa nuit      18435
# 24            24                       2001: A Space Odyssey   56700000
# 25            25                20,000 Leagues Under the Sea   28200000
# 26            26                20,000 Leagues Under the Sea    8000000
# 27            27                     24 7: Twenty Four Seven      72544
# 28            28                            Twin Falls Idaho     985341
# 29            29  Three Kingdoms: Resurrection of the Dragon          0
# ...          ...                                         ...        ...
# 3115        3115                      Extraordinary Measures   12482741
# 3116        3116                                       X-Men  157299717
# 3117        3117                                          X2  214949694
# 3118        3118                       X-Men: The Last Stand  234362462
# 3119        3119                          The Exploding Girl      25572
# 3120        3120                             The Expendables  101384023
# 3121        3121                     XXX: State of the Union   26873932
# 3122        3122                                   The Yards     882710
# 3123        3123  The Divine Secrets of the Ya-Ya Sisterhood   69586544
# 3124        3124                         You Can Count on Me    9180275
# 3125        3125                                    Year One   43337279
# 3126        3126                                         Yes     396035
# 3127        3127                                     Yes Man   97690976
# 3129             Comedy  Contemporary Fiction        Raja Gosnell
# 3130              Drama  Contemporary Fiction         Nora Ephron
# 3131             Comedy  Contemporary Fiction                  NA
# 3132              Drama  Contemporary Fiction      Alfonso Cuaron
# 3133          Adventure          Kids Fiction                  NA
# 3134                 NA                    NA                  NA
# 3135              Drama         Dramatization                  NA
# 3136          Adventure               Fantasy         Jon Favreau
# 3137             Comedy  Contemporary Fiction                  NA
# 3138             Comedy  Contemporary Fiction         Ben Stiller
# 3139             Comedy               Fantasy     Ruben Fleischer
# 3140             Comedy  Contemporary Fiction         Kevin Smith
# 3141  Thriller/Suspense         Dramatization       David Fincher
# 3142          Adventure            Super Hero        Peter Hewitt
# 3143          Adventure    Historical Fiction     Martin Campbell
# 3144          Adventure    Historical Fiction     Martin Campbell
#
#      Rotten Tomatoes Rating IMDB Rating IMDB Votes
# 0                        NA         6.1     1071.0
# 1                        NA         6.9      207.0
# 2                        NA         6.8      865.0
# 3                      13.0          NA         NA
# 4                      62.0         3.4      165.0
# 5                        NA          NA         NA
# 6                        NA         7.7    15133.0
# 7                        NA         3.8      353.0
# 8                      25.0         5.8     3275.0
# 9                      86.0         7.0     2906.0
# 10                     81.0         7.0     4035.0
# 11                     84.0         7.5     9111.0
# 12                     97.0         8.4    82786.0
# 13                       NA          NA         NA
# 14                     87.0         6.8     1532.0
# 15                       NA          NA         NA
# 16                       NA         7.0      451.0
# 17                       NA         6.1      858.0
# 18                     90.0         2.5     1677.0
# 19                       NA         8.9   119101.0
# 20                       NA         8.1   169858.0
# 21                     57.0         7.0     4099.0
# 22                     33.0         5.6    13364.0
# 23                       NA         6.3      365.0
# 24                     96.0         8.4   160342.0
# 25                     92.0          NA         NA
# 26                       NA          NA         NA
# 27                       NA         6.9     1417.0
# 28                     77.0         7.1     2810.0
# 29                       NA          NA         NA
# ...                     ...         ...        ...
# 3115                   27.0         6.4     3770.0
# 3116                   82.0         7.4   120706.0
# 3117                     NA         7.8   112320.0
# 3118                   57.0         6.9   109125.0
# 3119                     NA         6.2      260.0
# 3120                   40.0         7.1    42427.0
# 3121                     NA         4.1    19527.0
# 3122                   64.0         6.3     8784.0
# 3123                     NA          NA         NA
# 3124                   95.0         7.7    14261.0
# 3125                   14.0         5.0    23091.0
# 3126                     NA          NA         NA
# 3127                   43.0         7.0    62150.0
# 3128                   78.0         6.7     9498.0
# 3129                     NA         7.6      259.0
# 3130                   68.0         6.2    52587.0
# 3131                     NA         6.7    14670.0
# 3132                     NA          NA         NA
# 3133                     NA          NA         NA
# 3134                     NA         4.5       98.0
# 3135                   76.0         7.2     8408.0
# 3136                   75.0          NA         NA
# 3137                   66.0         6.8     8489.0
# 3138                   62.0         6.4    69296.0
# 3139                   89.0         7.8    81629.0
# 3140                   65.0         7.0    55687.0
# 3141                   89.0          NA         NA
# 3142                    3.0         3.4     7424.0
# 3143                   26.0         5.7    21161.0
# 3144                   82.0         6.7     4789.0
#
# [3145 rows x 17 columns]
